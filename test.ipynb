# %%
import tkinter as tk

root = tk.Tk()
root.title("My Tkinter Application")
lb = tk.label(master = root, text ="Hello world")
text = tk.text(root, height = 3)
entry = tk.Entry(root)
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox

root = tk.Tk()
root.title("Tic-Tac-Toe")

current_player = "X"
board = [["" for _ in range(3)] for _ in range(3)]
buttons = []

label_x = tk.Label(root, text="Player 1: X", font=("Arial", 14))
label_o = tk.Label(root, text="Player 2: O", font=("Arial", 14))
label_turn = tk.Label(root, text="Turn: X", font=("Arial", 16, "bold"))

label_x.grid(row=0, column=0, pady=5)
label_o.grid(row=0, column=2, pady=5)
label_turn.grid(row=0, column=1, pady=5)

def check_winner():
    for i in range(3):
        if board[i][0] == board[i][1] == board[i][2] != "":
            return True


    for i in range(3):
        if board[0][i] == board[1][i] == board[2][i] != "":
            return True

    if board[0][0] == board[1][1] == board[2][2] != "":
        return True

    if board[0][2] == board[1][1] == board[2][0] != "":
        return True

    return False

def board_full():
    for row in board:
        if "" in row:
            return False
    return True

def on_click(r, c):
    global current_player

    if board[r][c] != "":
        return

    board[r][c] = current_player
    buttons[r][c]["text"] = current_player

    if check_winner():
        messagebox.showinfo("Game Over", f"Player {current_player} wins!")
        root.destroy()
        return

    if board_full():
        messagebox.showinfo("Game Over", "It's a draw!")
        root.destroy()
        return

    current_player = "O" if current_player == "X" else "X"
    label_turn["text"] = f"Turn: {current_player}"

for r in range(3):
    row_buttons = []
    for c in range(3):
        btn = tk.Button(
            root,
            text="",
            width=8,
            height=3,
            font=("Arial", 20),
            command=lambda r=r, c=c: on_click(r, c)
        )
        btn.grid(row=r + 1, column=c, padx=5, pady=5)
        row_buttons.append(btn)
    buttons.append(row_buttons)

root.mainloop()

# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1

    while left <= right:
        mid = (left + right) // 2

        if arr[mid] == target:
            return True
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    return False

print(binary_search([1, 2, 3, 5, 8], 6))  # False
print(binary_search([1, 2, 3, 5, 8], 5))  # True
# Out:
# False
# True

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

print(bubble_sort([29, 13, 22, 37, 52, 49, 46, 71, 56]))
# Out:
# [13, 22, 29, 37, 46, 49, 52, 56, 71]

# %%
age = [23,43,45,76,83,83]
print(age)
# Out:
# [23, 43, 45, 76, 83, 83]

# %%
import tkinter as tk
window = tk.Tk()
label = tk.Label(text="Hello, Tkinter")
label = tk.Label(
    text="Hello, Tkinter",
    fg="white",
    bg="black",
    width=10,
    height=10

)
label.pack()
button = tk.Button(
    text="Hello, Tkinter",
    width=25,
    height=5,
    bg="red",
    fg="yellow",
)
button.pack()
window.mainloop()

# %%
from tkinter import*

root=Tk()
L1=Label( root, text="Enter your name:", font=40)
L1.grid( row=0, column=1)

E1=Entry(root)
E1.grid(row=0, column=1)

B1=Button(root, text="submit", font=40)
B1.grid(row=2, column=1)

root.mainloop()

# %%
from tkinter import *

root = Tk()

L1 = Label(root, text="Enter your name:", font=40)
L1.grid(row=0, column=0)  # Label on left

E1 = Entry(root, font=("Times New Roman", 20), width= 20, )
E1.grid(row=0, column=1)  # Entry on right
def C1():
    L2=Label(LF, text=E1.get(). lower())
    L2.pack()
    E1.insert(0, "#")
B1 = Button(root, text="Submit", font=40, command=C1 )
B1.grid(row=1, column=1)  # Button below entry

LF=LabelFrame(root, text="Output")
LF.grid(row=3, column=1)

root.mainloop()

# %%
from tkinter import *

root = Tk()

L1 = Label(root, text="Enter your name:", font=40)
L1.grid(row=0, column=0)  

E1 = Entry(root, font=("Times New Roman", 20), width= 20, )
E1.grid(row=0, column=1)  
def C1():
    L2=Label(root, text=E1.get())
    L2.grid(row=3, column=1)
B1 = Button(root, text="Submit", font=40, command=C1 )
B1.grid(row=1, column=1)  

root.mainloop()

# %%
import tkinter as tk


def fahrenheit_to_celsius():
    try:
       
        f = float(ent_temperature.get())
        c = (f - 32) * 5 / 9
        c_rounded = round(c, 2)
        lbl_result.config(text=f"{c_rounded}\N{DEGREE CELSIUS}")
    except ValueError:
        
        lbl_result.config(text="Invalid input")

window = tk.Tk()
window.title("Temperature Converter")
window.resizable(width=False, height=False)

frm_entry = tk.Frame(master=window)

ent_temperature = tk.Entry(master=frm_entry, width=10)
ent_temperature.grid(row=0, column=0, sticky="e")

lbl_temp = tk.Label(master=frm_entry, text="\N{DEGREE FAHRENHEIT}")
lbl_temp.grid(row=0, column=1, sticky="w")

frm_entry.grid(row=0, column=0, padx=10)


btn_convert = tk.Button(master=window, text="\N{RIGHTWARDS BLACK ARROW}", command=fahrenheit_to_celsius)
btn_convert.grid(row=0, column=1, pady=10)

lbl_result = tk.Label(master=window, text="\N{DEGREE CELSIUS}")
lbl_result.grid(row=0, column=2, padx=10)

window.mainloop()

# %%
import tkinter as tk
#grok

# Step 2: Define the conversion function
def fahrenheit_to_celsius():
    """Convert Fahrenheit to Celsius and update the result label."""
    try:
        fahrenheit = float(ent_temperature.get())
        celsius = (fahrenheit - 32) * 5 / 9
        celsius_rounded = round(celsius, 2)
        lbl_result.config(text=f"{celsius_rounded}\N{DEGREE CELSIUS}")
    except ValueError:
        lbl_result.config(text="Invalid input")

# Step 3: Create the main window
window = tk.Tk()
window.title("Temperature Converter")

# Step 4: Prevent resizing
window.resizable(width=False, height=False)

# Step 5: Frame for the entry and Fahrenheit label
frm_entry = tk.Frame(master=window)

# Step 6 & 7: Entry widget and Fahrenheit label
ent_temperature = tk.Entry(master=frm_entry, width=10)
lbl_temp = tk.Label(master=frm_entry, text="\N{DEGREE FAHRENHEIT}")

# Step 8: Grid the entry and label inside the frame
ent_temperature.grid(row=0, column=0, sticky="e")
lbl_temp.grid(row=0, column=1, sticky="w")

# Step 9: Convert button
btn_convert = tk.Button(
    master=window,
    text="\N{RIGHTWARDS BLACK ARROW}",
    command=fahrenheit_to_celsius
)

# Step 10: Result label (initially shows just the degree symbol)
lbl_result = tk.Label(master=window, text="\N{DEGREE CELSIUS}")

# Step 11: Grid everything on the main window
frm_entry.grid(row=0, column=0, padx=10)
btn_convert.grid(row=0, column=1, pady=10)
lbl_result.grid(row=0, column=2, padx=10)

# Optional: Add some padding and focus the entry on startup
ent_temperature.pack(padx=10, pady=10)  # Actually not needed because of grid above
window.update_idletasks()
ent_temperature.focus()

# Step 12: Start the event loop
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[69], line 49
#      46 lbl_result.grid(row=0, column=2, padx=10)
#      48 # Optional: Add some padding and focus the entry on startup
# ---> 49 ent_temperature.pack(padx=10, pady=10)  # Actually not needed because of grid above
#      50 window.update_idletasks()
#      51 ent_temperature.focus()
#
# File c:\Users\Aliy Ayodeji\AppData\Local\Python\pythoncore-3.14-64\Lib\tkinter\__init__.py:2610, in Pack.pack_configure(self, cnf, **kw)
#    2594 def pack_configure(self, cnf={}, **kw):
#    2595     """Pack a widget in the parent widget. Use as options:
#    2596     after=widget - pack it after you have packed widget
#    2597     anchor=NSEW (or subset) - position widget according to
#    (...)   2608     side=TOP or BOTTOM or LEFT or RIGHT -  where to add this widget.
#    2609     """
# -> 2610     self.tk.call(
# ...
